# %%
import pandas as pd
import numpy as np

# %%
path='C:\Users\issam\Downloads\auto1.csv'
df = pd.read_csv(path)
df.head()
# Out:
#   File "<ipython-input-1-c49f78183acd>", line 1
#     path='C:\Users\issam\Downloads\auto1.csv'
#          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
# %%capture
! pip install seaborn

# %%
df['highway-mpg']=df['highway-mpg'].astype('float')

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
sns.regplot(x='engine-size',y='price',data=df)
plt.ylim(0,)
df[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
df[['highway-mpg','price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sns.regplot(x='peak-rpm',y='price',data=df)
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
sns.regplot(x='stroke',y='price',data=df)
df[['stroke','price']].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %%
sns.boxplot(x='body-style', y='price',data=df)

# %%
sns.boxplot(x='engine-location', y='price',data=df)

# %%
sns.boxplot(x="drive-wheels", y="price", data=df)

# %%
### we see that there is a big difference between drive wheels and price and engine locations and price therefore these could be a good predictor of price.

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
drivewheelcounts=df['drive-wheels'].value_counts().to_frame()

# %%
drivewheelcounts.rename(columns={'drive-wheels':'value_counts'}, inplace= True)
drivewheelcounts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %%
engine_loc_counts = df['engine-location'].value_counts().to_frame()
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)
engine_loc_counts.index.name = 'engine-location'
engine_loc_counts.head(10)
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
df1=df[['drive-wheels','body-style','price']]
df1grouped=df1.groupby(['drive-wheels','body-style'],as_index=False).mean()

# %%
df1grouped
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
df1pivot=df1grouped.pivot(index='drive-wheels',columns='body-style')
df1pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
groupedpivot= df1pivot.fillna(0)

# %%
groupedpivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
df2=df[['body-style','price']]
df2grouped=df2.groupby(['body-style'],as_index=False).mean()
df2grouped
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %%
meanofpriceconvertible=df[df['body-style']=='convertible']['price'].mean()

# %%
plt.pcolor(groupedpivot, cmap='RdBu')
plt.colorbar()
plt.show()

# %%
fig, ax = plt.subplots()
im = ax.pcolor(groupedpivot, cmap='RdBu')

#label names
row_labels = groupedpivot.columns.levels[1]
col_labels = groupedpivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(groupedpivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(groupedpivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(df['wheel-base'],df['price'])
print('The pearson Correlation Coefficient is = ', pearson_coef, 'with a P value of =', p_value)
### weak correlation that we are certain of
# Out:
# The pearson Correlation Coefficient is =  0.5846418222655081 with a P value of = 8.076488270732989e-20

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'],df['price'])
print('The pearson Correlation Coefficient is = ', pearson_coef, 'with a P value of =', p_value)
### strong correlation that we are certain of
# Out:
# The pearson Correlation Coefficient is =  0.809574567003656 with a P value of = 6.369057428259557e-48

# %%
pearson_coef, p_value = stats.pearsonr(df['length'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)  
###moderately strong positive correlation that we are certain of
# Out:
# The Pearson Correlation Coefficient is 0.690628380448364  with a P-value of P =  8.016477466158986e-30

# %%
pearson_coef, p_value = stats.pearsonr(df['width'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
### strong correlation that we are certain of
# Out:
# The Pearson Correlation Coefficient is 0.7512653440522674  with a P-value of P = 9.200335510481516e-38

# %%
pearson_coef, p_value = stats.pearsonr(df['curb-weight'], df['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)  
### strong correlation that we are certain of
# Out:
# The Pearson Correlation Coefficient is 0.8344145257702846  with a P-value of P =  2.1895772388936914e-53

# %%
pearson_coef, p_value = stats.pearsonr(df['engine-size'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value) 
### very strong correlation that we are certain of
# Out:
# The Pearson Correlation Coefficient is 0.8723351674455185  with a P-value of P = 9.265491622198389e-64

# %%
pearson_coef, p_value = stats.pearsonr(df['bore'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =  ", p_value ) 
### moderate correlation that we are certain of
# Out:
# The Pearson Correlation Coefficient is 0.5431553832626602  with a P-value of P =   8.049189483935489e-17

# %%
pearson_coef, p_value = stats.pearsonr(df['city-mpg'], df['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)  
### negative moderately strong correlation that we are certain of
# Out:
# The Pearson Correlation Coefficient is -0.6865710067844677  with a P-value of P =  2.321132065567674e-29

# %%
pearson_coef, p_value = stats.pearsonr(df['highway-mpg'], df['price'])
print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value ) 
###Negative moderately strong correlation that we are certain of
# Out:
# The Pearson Correlation Coefficient is -0.7046922650589529  with a P-value of P =  1.7495471144477352e-31

# %%
grouptest2=df1[['drive-wheels','price']].groupby(['drive-wheels'])
grouptest2.head()
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 2            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 6            fwd  17710.0
# 7            fwd  18920.0
# 8            fwd  23875.0
# 9            rwd  16430.0
# 10           rwd  16925.0
# 136          4wd   7603.0
# 140          4wd   9233.0
# 141          4wd  11259.0
# 144          4wd   8013.0

# %%
df1
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
grouptest2.get_group('4wd')['price'].to_frame()
# Out:
#        price
# 4    17450.0
# 136   7603.0
# 140   9233.0
# 141  11259.0
# 144   8013.0
# 145  11694.0
# 150   7898.0
# 151   8778.0

# %%
f_val, p_val = stats.f_oneway(grouptest2.get_group('fwd')['price'],grouptest2.get_group('rwd')['price'],grouptest2.get_group('4wd')['price'])
print('Anova Results: F=', f_val, ", P =", p_val)
### strong correlation with strong P value
# Out:
# Anova Results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %%
#### to see if all tested groups are correlated:

# %%
f_val, p_val = stats.f_oneway(grouptest2.get_group('fwd')['price'], grouptest2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %%
f_val, p_val = stats.f_oneway(grouptest2.get_group('4wd')['price'], grouptest2.get_group('rwd')['price'])  
   
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 8.580681368924756 , P = 0.004411492211225333

# %%
f_val, p_val = stats.f_oneway(grouptest2.get_group('4wd')['price'], grouptest2.get_group('fwd')['price'])  
 
print("ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 0.665465750252303 , P = 0.41620116697845666

# %%
meanofpriceconvertible
# Out:
# 21890.5

# %%
meanofpricehardtop=df[df['body-style']=='hardtop']['price'].mean()

# %%
meanofpricehardtop
# Out:
# 22208.5

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
x=df[['highway-mpg']]
y=df['price']

# %%
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
lm.predict([[30]])
# Out:
# array([13771.3045085])

# %%
lm.coef_
# Out:
# array([-821.73337832])

# %%
lm.intercept_
# Out:
# 38423.3058581574

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
plt.ylim(0)
# Out:
# (0.0, 48174.982691978155)

# %%
x2=df[['horsepower']]
y2=df['price']
lm.fit(x2,y2)
lm.predict([[200]])
# Out:
# array([29839.06608465])

# %%
sns.regplot(x='horsepower',y='price',data=df)
plt.ylim(0)
# Out:
# (0.0, 47537.05730191001)

# %%
lm.intercept_
# Out:
# -4597.558297892912

# %%
lm.coef_
# Out:
# array([172.18312191])

# %%
z=df[['horsepower','curb-weight','engine-size','highway-mpg']]
lm.fit(z,df['price'])
# Out:
# LinearRegression()

# %%
Yhat=lm.predict([[150,2000,150,50]])

# %%
Yhat
# Out:
# array([15665.55301081])

# %%
lm.intercept_
# Out:
# -15806.624626329198

# %%
lm.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %% [markdown]
# Price = -15806.624626329198 + (53.49574423) * horsepower + (4.70770099) * curb weight + 81.53026382* engine size + 36.05748882 * highwaympg

# %%
### RESIDUAL PLOT, DIFFERENCES BETWEEN ACTUAL AND MODEL VALUES SCATTERED

sns.residplot(df['highway-mpg'],df['price'])

# %% [markdown]
# Since it has a curvature, it is not a good model.

# %%
sns.residplot(df['horsepower'],df['price'])

# %%
### DISTRIBUTION PLOT, SHOWS HOW OUR MODEL IS DISTRIBUTED VS HOW THE DATA IS DISTRIBUTED

Yhat=lm.predict(z)
ax1=sns.distplot(df['price'],hist=False, color='r', label='Actual Value')
sns.distplot(Yhat, hist=False, color='b', label="Fitted Values", ax=ax1)

# %%
lm.score(z,df['price'])
# Out:
# 0.8093562806577457

# %%
f=np.polyfit(df['horsepower'],df['price'],2)
p=np.poly1d(f)

# %%
print(p)
# Out:
#         2
# 0.2054 x + 121 x - 1786

# %%
xhp=df[['highway-mpg','horsepower','curb-weight','engine-size']]
yhp=df['price']
Yhathp=lm.predict(xhp)
axhp=sns.distplot(df['price'],hist=False,color='r',label='Actual Value')
sns.distplot(Yhathp,hist=False, color='b',label='Fitted Value', ax=axhp)

# %%
xxx=df[['horsepower']]
yyy=df['price']
lm.fit(xxx,yyy)
Yhatxxx=lm.predict(xxx)
axxxx=sns.distplot(yyy,hist=False,color='r',label='Actual Value')
sns.distplot(Yhatxxx,hist=False,color='b',label='Fitted Value',ax=axxxx)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures(degree=2,include_bias=False)

# %%
pr.fit_transform(df[['horsepower','highway-mpg']],df['price'])
# Out:
# array([[1.1100e+02, 2.7000e+01, 1.2321e+04, 2.9970e+03, 7.2900e+02],
#        [1.1100e+02, 2.7000e+01, 1.2321e+04, 2.9970e+03, 7.2900e+02],
#        [1.5400e+02, 2.6000e+01, 2.3716e+04, 4.0040e+03, 6.7600e+02],
#        ...,
#        [1.3400e+02, 2.3000e+01, 1.7956e+04, 3.0820e+03, 5.2900e+02],
#        [1.0600e+02, 2.7000e+01, 1.1236e+04, 2.8620e+03, 7.2900e+02],
#        [1.1400e+02, 2.5000e+01, 1.2996e+04, 2.8500e+03, 6.2500e+02]])

# %%
from sklearn.preprocessing import StandardScaler
SCALE=StandardScaler()

# %%
SCALE.fit(df[['horsepower','highway-mpg']])
# Out:
# StandardScaler()

# %%
x_scale=SCALE.transform(df[['horsepower','highway-mpg']])

# %%
from sklearn.pipeline import Pipeline

# %%
Input=[('scale',StandardScaler()),('polynomial',PolynomialFeatures(degree=4)),('mode',LinearRegression())]

# %%
pipe=Pipeline(Input)

# %%
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(degree=4)),
#                 ('mode', LinearRegression())])

# %%
pipe.fit(df[['engine-size','curb-weight','horsepower','highway-mpg']],df['price'])
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(degree=4)),
#                 ('mode', LinearRegression())])

# %%
yhat=pipe.predict(df[['engine-size','curb-weight','horsepower','highway-mpg']])

# %%
axxxx=sns.distplot(df['price'],hist=False,color='r',label='Actual Value')
sns.distplot(df[['engine-size','curb-weight','horsepower','highway-mpg']],hist=False,color='b',label='Fitted Value',ax=axxxx)

# %%
yhat=pipe.predict([[150,2000,150,50]])

# %%
yhat
# Out:
# array([-648189.])

# %%
### TO CALCULATE MEAN SQUARED ERROR TO SEE IF MODEL IS VALID 
from sklearn.metrics import mean_squared_error

# %%
yhat=pipe.predict(df[['horsepower','curb-weight','engine-size','highway-mpg']])
mean_squared_error(df['price'],yhat)
# Out:
# 43814273176.01088

# %%
### TO CALCULATE R E2 OR R SQUARED 
x=df[['horsepower','curb-weight','engine-size','highway-mpg']]
y=df['price']
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
### R E2 VAULE IS CLOSE TO ONE SO THIS IS A GOOD MODEL
lm.score(x,y)
# Out:
# 0.8093562806577457

# %%
#### PREDICTION AND DECISION MAKING 


lm.fit(df[['engine-size']],df['price'])
# Out:
# LinearRegression()

# %%
lm.predict(np.array(30.0).reshape(-1,1))
# Out:
# array([-2957.53843554])

# %%
lm.predict([[30]])
# Out:
# array([-2957.53843554])

# %%
lm.coef_
# Out:
# array([166.86001569])

# %%
lm.intercept_
# Out:
# -7963.338906281049

# %%
new_input=np.arange(1,101,1).reshape(-1,1)

# %%
yhat=lm.predict(new_input)

# %%
ax1=sns.distplot(df['price'],hist=False, color='r', label='Actual Value')
sns.distplot(yhat, hist=False, color='b', label="Fitted Values", ax=ax1)

# %%
sns.regplot(x='highway-mpg',y='price',data=df)
plt.ylim(0)
# Out:
# (0.0, 48169.3193702948)

# %%
sns.residplot(df['highway-mpg'],df['price'])

# %%
yhat=lm.predict(df[['engine-size']])
ax1=sns.distplot(df['price'],hist=False, color='r', label='Actual Value')
sns.distplot(yhat, hist=False, color='b', label="Fitted Values", ax=ax1)

# %%
lm.fit(df[['engine-size']],df['price'])
lm.score(df[['engine-size']],df['price'])
# Out:
# 0.7609686443622008

# %%
lm.fit(df[['horsepower']],df['price'])
lm.score(df[['horsepower']],df['price'])
# Out:
# 0.6554109795391572

# %%
lm.fit(df[['highway-mpg']],df['price'])
lm.score(df[['highway-mpg']],df['price'])
# Out:
# 0.4965911884339176

# %%
lm.fit(df[['curb-weight']],df['price'])
lm.score(df[['curb-weight']],df['price'])
# Out:
# 0.6962476008164488

# %%
bettermodel=df[['engine-size','curb-weight','horsepower','highway-mpg']]
lm.fit(bettermodel,df['price'])
# Out:
# LinearRegression()

# %%
Yhat=lm.predict(bettermodel)
ax1=sns.distplot(df['price'],hist=False, color='r', label='Actual Value')
sns.distplot(Yhat, hist=False, color='b', label="Fitted Values", ax=ax1)

# %%
lm.predict([[150,2000,150,50]])
# Out:
# array([15665.55301081])

# %%
lm.score(bettermodel,df['price'])
# Out:
# 0.8093562806577457

# %%
firstmodel=df[['horsepower','curb-weight','engine-size','highway-mpg']]
lm.score(firstmodel,df['price'])
# Out:
# 0.7953980992204785

# %%
Yhat=lm.predict(firstmodel)
ax1=sns.distplot(df['price'],hist=False, color='r', label='Actual Value')
sns.distplot(Yhat, hist=False, color='b', label="Fitted Values", ax=ax1)

# %%
### HAVE CREATED A BETTER MODEL ALONE !!! :):):):)::):):)
Yhat=lm.predict(bettermodel)

# %%
pipe.fit(bettermodel,df['price'])
yhat=pipe.predict(df[['engine-size','curb-weight','horsepower','highway-mpg']])
mean_squared_error(df['price'],yhat)
# Out:
# 3675094.1333955224

# %%
pipe.fit(firstmodel,df['price'])
yhat2=pipe.predict(df[['horsepower','curb-weight','engine-size','highway-mpg']])
mean_squared_error(df['price'],yhat2)
# Out:
# 3675105.4654850746

# %%
from scipy import stats
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'horsepower-binned', 'diesel', 'gas'],
#       dtype='object')

# %%
pearson_coef, p_value= stats.pearsonr(df['engine-size'],df['price'])
print(pearson_coef, p_value)
# Out:
# 0.8723351674455185 9.265491622198389e-64

# %%
pearson_coef, p_value= stats.pearsonr(df['curb-weight'],df['price'])
print(pearson_coef, p_value)
# Out:
# 0.8344145257702846 2.1895772388936914e-53

# %%
pearson_coef, p_value= stats.pearsonr(df['horsepower'],df['price'])
print(pearson_coef,p_value)
# Out:
# 0.809574567003656 6.369057428259557e-48

# %%
pearson_coef, p_value= stats.pearsonr(df['city-L/100km'],df['price'])
print(pearson_coef,p_value)
# Out:
# 0.7898975136626941 3.903106400940024e-44

# %%
### We are not very certain of results in this one
pearson_coef, p_value= stats.pearsonr(df['width'],df['price'])
print(pearson_coef,p_value)
# Out:
# 0.7512653440522674 9.200335510481516e-38

# %%
pearson_coef, p_value= stats.pearsonr(df['highway-mpg'],df['price'])
print(pearson_coef,p_value)
# Out:
# -0.7046922650589529 1.7495471144477352e-31

# %%
pearson_coef, p_value= stats.pearsonr(df['length'],df['price'])
print(pearson_coef,p_value)
# Out:
# 0.690628380448364 8.016477466158986e-30

# %%
### BUILDING EVEN BETTER MODEL AS WE HAVE NOTICED DIFFERENCES THROUGH DF.CORR()
pipe.fit(df[['engine-size','curb-weight','horsepower','city-L/100km','width','highway-mpg','length']],df['price'])
Input=[('scale',StandardScaler()),('polynomial',PolynomialFeatures(degree=7)),('mode',LinearRegression())]

# %%
BESTMODEL= df[['engine-size','curb-weight','horsepower','city-L/100km','width','highway-mpg','length']]
yhat=pipe.predict(df[['engine-size','curb-weight','horsepower','city-L/100km','width','highway-mpg','length']])
mean_squared_error(df['price'],yhat)
# Out:
# 86180.92498931126

# %%
lm.fit(BESTMODEL,df['price'])
yhat=lm.predict(BESTMODEL)
ax1=sns.distplot(df['price'],hist=False, color='r', label='Actual Value')
sns.distplot(yhat, hist=False, color='b', label="Fitted Values", ax=ax1)
plt.title('Actual Vs Fitted Best Model')
plt.xlabel('Price in dollars')
plt.ylabel('Proportion of cars')
plt.show()

# %%
lm.score(BESTMODEL,df['price'])
# Out:
# 0.8319254008512564

# %%
mse=mean_squared_error(df['price'],yhat)
mse
# Out:
# 10562086.002095472

# %%
####BEST MODEL !

# %%
lm.intercept_
# Out:
# -66584.62242991965

# %%
lm.fit(bettermodel,df['price'])
# Out:
# LinearRegression()

# %%
lm.score(bettermodel,df['price'])
# Out:
# 0.8093562806577457

# %%
yhat[0:4]
# Out:
# array([13061.62426152, 13061.62426152, 18607.43158558, 10702.49149775])

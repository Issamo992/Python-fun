# %%
import pandas as pd

# %%
path='/Users/issam/OneDrive/Documents/Datasets/housing.csv'
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.describe(include='all')
# Out:
#            longitude      latitude  housing_median_age   total_rooms  \
# count   20640.000000  20640.000000        20640.000000  20640.000000
# unique           NaN           NaN                 NaN           NaN
# top              NaN           NaN                 NaN           NaN
# freq             NaN           NaN                 NaN           NaN
# mean     -119.569704     35.631861           28.639486   2635.763081
# std         2.003532      2.135952           12.585558   2181.615252
# min      -124.350000     32.540000            1.000000      2.000000
# 25%      -121.800000     33.930000           18.000000   1447.750000
# 50%      -118.490000     34.260000           29.000000   2127.000000
# 75%      -118.010000     37.710000           37.000000   3148.000000
# max      -114.310000     41.950000           52.000000  39320.000000
#
#         total_bedrooms    population    households  median_income  \
# count     20433.000000  20640.000000  20640.000000   20640.000000
# ...

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
type(df.loc[0,'latitude'])
# Out:
# numpy.float64

# %%
df.iloc[0]
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age          41
# total_rooms                880
# total_bedrooms             129
# population                 322
# households                 126
# median_income           8.3252
# median_house_value      452600
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %%
type(df.iloc[1:,1])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc[df['total_bedrooms'].isna()]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
df['total_bedrooms'].isna().sum()/len(df)
# Out:
# 0.01002906976744186

# %%
filtered_df=df.dropna()

# %%
filtered_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df['households'].isna().sum()
# Out:
# 0

# %%
newdf=df[-[df.total_bedrooms.isna()]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-a56d6e9f57cf> in <module>
# ----> 1 newdf=df[-[df_total_bedrooms.isna()]]
#
# NameError: name 'df_total_bedrooms' is not defined

# %%
newdf
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0            NaN       NaN                 NaN          NaN             NaN
# 1            NaN       NaN                 NaN          NaN             NaN
# 2            NaN       NaN                 NaN          NaN             NaN
# 3            NaN       NaN                 NaN          NaN             NaN
# 4            NaN       NaN                 NaN          NaN             NaN
# ...          ...       ...                 ...          ...             ...
# 20635        NaN       NaN                 NaN          NaN             NaN
# 20636        NaN       NaN                 NaN          NaN             NaN
# 20637        NaN       NaN                 NaN          NaN             NaN
# 20638        NaN       NaN                 NaN          NaN             NaN
# 20639        NaN       NaN                 NaN          NaN             NaN
#
# ...

# %%
newdf=df[-df.total_bedrooms.isna()]
newdf
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df[df['total_bedrooms']>1000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
newdf['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
newdf['ocean_proximity'].value_counts().hist()

# %%
newdf['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
dicc={'NEAR BAY':0, '<1H OCEAN':10, 'INLAND':100, 'NEAR OCEAN':5, 'ISLAND':-1}

# %%
newdf.replace['NEAR BAY','ocean_proximity']= 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-114ebbe8a36b> in <module>
# ----> 1 newdf.replace['NEAR BAY','ocean_proximity']= 0
#
# TypeError: 'method' object does not support item assignment

# %%
filter2 = newdf.replace(dicc)

# %%
newdf['replace_method']=newdf.ocean_proximity.replace(dicc)

# %%
newdf
# Out:
#            longitude  latitude  housing_median_age  total_rooms  \
# 0            -122.23     37.88                41.0        880.0
# 1            -122.22     37.86                21.0       7099.0
# 2            -122.24     37.85                52.0       1467.0
# 3            -122.25     37.85                52.0       1274.0
# 4            -122.25     37.85                52.0       1627.0
# ...              ...       ...                 ...          ...
# 20637        -121.22     39.43                17.0       2254.0
# 20638        -121.32     39.43                18.0       1860.0
# 20639        -121.24     39.37                16.0       2785.0
# NEAR BAY        0.00      0.00                 0.0          0.0
# <1H OCEAN        NaN       NaN                 NaN          NaN
#
#            total_bedrooms  population  households  median_income  \
# 0                   129.0       322.0       126.0         8.3252
# ...

# %%
filter2=filter2.drop('replace_method',axis=1)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
df.info('total_bedrooms')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
newdf.groupby(['ocean_proximity']).agg({'longitude':'mean','latitude':'mean','population':'sum',}).sort_values(by='population')
# Out:
#                   longitude   latitude  population
# ocean_proximity
# 0                  0.000000   0.000000         0.0
# ISLAND          -118.354000  33.358000      3340.0
# NEAR BAY        -122.261035  37.801304   2787290.0
# NEAR OCEAN      -119.329836  34.736065   3562615.0
# INLAND          -119.733085  36.731806   9045105.0
# <1H OCEAN       -118.848642  34.560734  13717591.0
